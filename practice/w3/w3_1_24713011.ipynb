# %% [markdown]
# https://www.kaggle.com/datasets/CooperUnion/cardataset?resource=download

# %% [markdown]
# ## **Car**
#
# ### Introduction
# What is Exploratory Data Analysis ?
#
# Exploratory Data Analysis or (EDA) is understanding the data sets by summarizing their main characteristics often plotting them visually. This step is very important especially when we arrive at modeling the data in order to apply Machine learning. Plotting in EDA consists of Histograms, Box plot, Scatter plot and many more. It often takes much time to explore the data. Through the process of EDA, we can ask to define the problem statement or definition on our data set which is very important.
#
# ### How to perform Exploratory Data Analysis ?
#
# This is one such question that everyone is keen on knowing the answer. Well, the answer is it depends on the data set that you are working. There is no one method or common methods in order to perform EDA, whereas in this tutorial you can understand some common methods and plots that would be used in the EDA process.

# %% [markdown]
# ### Types of exploratory data analysis
#
# There are four types of exploratory data analysis:
#
# 1️⃣ Univariate non-graphic. This is the simplest form of data analysis and the data analyzed consists of only one variable. Since it is a single variable, it does not deal with causes or relationships. The main purpose of univariate analysis is to identify data and find patterns that exist in it.
#
# 2️⃣ Bivariate, graphic. Non-graphical methods do not provide a complete picture of the data.  Therefore, graphical methods are required.  Common bivariate chart types include: 👇🏻
#
# 🔹️ Root and leaf plots showing all data values ​​and the shape of the distribution.
#
# 🔹️ Histograms, which are a bar plot where each bar represents the frequency (number) or proportion (number/total number) for a range of values.
#
# 🔹️ Box charts that graphically display a five-figure summary of the minimum, first quarter, median, third quarter, and maximum values.
#
# 3️⃣ Multivariate non-graphic: Multivariate data arises according to more than one variable.  Multivariate non-graphical EDA techniques show the relationship between two or more variables of the data, often through cross tabulation or statistics.
#
# 4️⃣ Multivariate graphic: Multivariate data uses charts to display relationships between two or more data sets. The most commonly used chart is a bar plot or bar chart grouped with each bar within a group representing one level of each group and the levels of the other variable.
#
# Other general types of multivariate graphs are:
#
# 🔸️ Scatterplot used to plot data points on the horizontal and vertical axes to show how much one variable is affected by another variable.
#
# 🔸️ Multivariate chart, which is a graphical representation of the relationships between factors and a response.
#
# 🔸️ Bubble chart, a data visualization that displays multiple circles (bubbles) in a two-dimensional drawing.
#
# 🔸️ Heatmap, which is a graphical representation of data with values ​​represented by colors.

# %% [markdown]
# ### Contents
#
# 1. Importing the required libraries for EDA
# 2. Loading the data into the data frame
# 3. Checking the types of data
# 4. Dropping irrelevant columns
# 5. Renaming the columns
# 6. Dropping the duplicate rows
# 7. Dropping the missing or null values
# 8. Detecting Outliers
# 9. Plot different features against one another (scatter), against frequency (histogram)
# 10. Univariate analysis (distribution)
# 11. Multivariate analysis (relationships)
# 12. Feature engineering (dummy variables, scaling, binning)
# 13. Summary
#
# Thank you.

# %% [markdown]
# ## **Practice**

# %% [markdown]
# 1.Importing the required libraries for EDA
#
# Below are the libraries that are used in order to perform EDA (Exploratory data analysis) in this tutorial.

# %%
# TODO: import pandas, numpy, matplotlib.pyplot, seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2.Loading the data into the data frame.
#
#
# Loading the data into the pandas data frame is certainly one of the most important steps in EDA, as we can see that the value from the data set is comma-separated. So all we have to do is to just read the CSV into a data frame and pandas data frame does the job for us.

# %%
# read file 
# df = ?
csv_file = "data.csv"
df = pd.read_csv(csv_file)
print("Loaded file:", csv_file)
# Out:
# Loaded file: data.csv

# %%
# To display the top 5 rows 
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
# 3                     Luxury,Performance      Compact         Coupe
# 4                                 Luxury      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350
# 3           28        18        3916  29450
# 4           28        18        3916  34500

# %%
 # To display the botton 5 rows
df.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 11909  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11910  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11911  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11912  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11913                      Luxury      Midsize          Sedan           26
#
#        city mpg  Popularity   MSRP
# 11909        16         204  46120
# 11910        16         204  56670
# 11911        16         204  50620
# 11912        16         204  50920
# 11913        17          61  28995

# %% [markdown]
# 3.Checking the types of data
#
# Here we check for the datatypes because sometimes the MSRP or the price of the car would be stored as a string, if in that case, we have to convert that string to the integer data only then we can plot the data via a graph. Here, in this case, the data is already in integer format so nothing to worry.

# %%
# TO DO
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  str
#  1   Model              11914 non-null  str
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  str
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  str
#  7   Driven_Wheels      11914 non-null  str
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   str
#  10  Vehicle Size       11914 non-null  str
#  11  Vehicle Style      11914 non-null  str
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# dtypes: float64(3), int64(5), str(8)
# memory usage: 1.5 MB

# %% [markdown]
# 4.Dropping irrelevant columns
#
# This step is certainly needed in every EDA because sometimes there would be many columns that we never use in such cases dropping is the only solution. In this case, the columns such as Engine Fuel Type, Market Category, Vehicle style, Popularity, Number of doors, Vehicle Size doesn't make any sense to me so I just dropped for this instance

# %%
# TODO: drop unused columns
df = df.drop(columns=['Engine Fuel Type', 'Market Category', 'Vehicle Style', 'Popularity', 'Number of Doors', 'Vehicle Size'])

# %%
df
# Out:
#           Make       Model  Year  Engine HP  Engine Cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       Transmission Type      Driven_Wheels  highway MPG  city mpg   MSRP
# 0                MANUAL   rear wheel drive           26        19  46135
# 1                MANUAL   rear wheel drive           28        19  40650
# 2                MANUAL   rear wheel drive           28        20  36350
# 3                MANUAL   rear wheel drive           28        18  29450
# 4                MANUAL   rear wheel drive           28        18  34500
# ...                 ...                ...          ...       ...    ...
# 11909         AUTOMATIC    all wheel drive           23        16  46120
# 11910         AUTOMATIC    all wheel drive           23        16  56670
# 11911         AUTOMATIC    all wheel drive           23        16  50620
# 11912         AUTOMATIC    all wheel drive           23        16  50920
# 11913         AUTOMATIC  front wheel drive           26        17  28995
#
# [11914 rows x 10 columns]

# %% [markdown]
# 5.Renaming the columns
#
# In this instance, most of the column names are very confusing to read, so I just tweaked their column names. This is a good approach it improves the readability of the data set.

# %%
# TODO: rename "Purchase Amount (USD)" → Amount, "Review Rating" → Rating, "Item Purchased" → Item
df = df.rename({"Perchase Amout (USD)":"Amount", "Review Rating":"Rating", "Item Purchased":"Item"})

# %%
df
# Out:
#           Make       Model  Year  Engine HP  Engine Cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       Transmission Type      Driven_Wheels  highway MPG  city mpg   MSRP
# 0                MANUAL   rear wheel drive           26        19  46135
# 1                MANUAL   rear wheel drive           28        19  40650
# 2                MANUAL   rear wheel drive           28        20  36350
# 3                MANUAL   rear wheel drive           28        18  29450
# 4                MANUAL   rear wheel drive           28        18  34500
# ...                 ...                ...          ...       ...    ...
# 11909         AUTOMATIC    all wheel drive           23        16  46120
# 11910         AUTOMATIC    all wheel drive           23        16  56670
# 11911         AUTOMATIC    all wheel drive           23        16  50620
# 11912         AUTOMATIC    all wheel drive           23        16  50920
# 11913         AUTOMATIC  front wheel drive           26        17  28995
#
# [11914 rows x 10 columns]

# %% [markdown]
# 6.Dropping the duplicate rows
#
# This is often a handy thing to do because a huge data set as in this case contains more than 10, 000 rows often have some duplicate data which might be disturbing, so here I remove all the duplicate value from the data-set. For example prior to removing I had 11914 rows of data but after removing the duplicates 10925 data meaning that I had 989 of duplicate data.

# %%
# TODO: check columns and data types
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11914 entries, 0 to 11913
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  str
#  1   Model              11914 non-null  str
#  2   Year               11914 non-null  int64
#  3   Engine HP          11845 non-null  float64
#  4   Engine Cylinders   11884 non-null  float64
#  5   Transmission Type  11914 non-null  str
#  6   Driven_Wheels      11914 non-null  str
#  7   highway MPG        11914 non-null  int64
#  8   city mpg           11914 non-null  int64
#  9   MSRP               11914 non-null  int64
# dtypes: float64(2), int64(4), str(4)
# memory usage: 1023.9 KB

# %%
# TODO: count the number of rows
print("so hang: ", df.shape[0])
# Out:
# so hang:  11914

# %% [markdown]
# Now let us remove the duplicate data because it's ok to remove them.

# %%
# TO DO  # Used to count the number of rows
print("so hang: ", df.shape[0])
dup = df.duplicated().sum()
print("so hang bi trung: ", dup)
# Out:
# so hang:  11914
# so hang bi trung:  989

# %%
# TODO: remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
# TODO: count after deleting duplicates
print("so hang sau xoa: ", df.shape[0])
# Out:
# so hang sau xoa:  10925

# %% [markdown]
# 7.Dropping the missing or null values.
#
# This is mostly similar to the previous step but in here all the missing values are detected and are dropped later. Now, this is not a good approach to do so, because many people just replace the missing values with the mean or the average of that column, but in this case, I just dropped that missing values.

# %%
# TODO: count missing values per column
missing = df.isnull().sum()
print(missing)
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine HP            69
# Engine Cylinders     30
# Transmission Type     0
# Driven_Wheels         0
# highway MPG           0
# city mpg              0
# MSRP                  0
# dtype: int64

# %%
# TODO Dropping the missing values.
df.dropna(inplace=True)

# %%
# TODO: count after dropping missing values
missing_after_dropping = df.isnull().sum()
print(missing_after_dropping)
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# highway MPG          0
# city mpg             0
# MSRP                 0
# dtype: int64

# %% [markdown]
# 8.Detecting Outliers¶
#
# An outlier is a point or set of points that are different from other points. Sometimes they can be very high or very low. It's often a good idea to detect and remove the outliers. Because outliers are one of the primary reasons for resulting in a less accurate model. Hence it's a good idea to remove them. The outlier detection and removing that I am going to perform is called IQR score technique. Often outliers can be seen with visualizations using a box plot. Shown below are the box plot of MSRP, Cylinders, Horsepower and EngineSize. Herein all the plots, you can find some points are outside the box they are none other than outliers. The technique of finding and removing outlier that I am performing in this assignment is taken help of a tutorial from towards data science.

# %%
df
# Out:
#           Make       Model  Year  Engine HP  Engine Cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       Transmission Type      Driven_Wheels  highway MPG  city mpg   MSRP
# 0                MANUAL   rear wheel drive           26        19  46135
# 1                MANUAL   rear wheel drive           28        19  40650
# 2                MANUAL   rear wheel drive           28        20  36350
# 3                MANUAL   rear wheel drive           28        18  29450
# 4                MANUAL   rear wheel drive           28        18  34500
# ...                 ...                ...          ...       ...    ...
# 11909         AUTOMATIC    all wheel drive           23        16  46120
# 11910         AUTOMATIC    all wheel drive           23        16  56670
# 11911         AUTOMATIC    all wheel drive           23        16  50620
# 11912         AUTOMATIC    all wheel drive           23        16  50920
# 11913         AUTOMATIC  front wheel drive           26        17  28995
#
# [10827 rows x 10 columns]

# %%
# TODO: plot a boxplot of Price
df.boxplot(column='MSRP')
plt.show()

# %%
# TODO: check HP outliers with a boxplot
df.boxplot(column='Engine HP')
plt.show()

# %%
# TODO: plot a boxplot of Cylinders
df.boxplot(column='Engine Cylinders')
plt.show()

# %%
Q1 = df.quantile(0.25, numeric_only=True)
Q3 = df.quantile(0.75, numeric_only=True)
IQR = Q3 - Q1
print(IQR)
# Out:
# Year                    9.0
# Engine HP             130.0
# Engine Cylinders        2.0
# highway MPG             8.0
# city mpg                6.0
# MSRP                21327.5
# dtype: float64

# %%
# TODO: compute Q1, Q3, and IQR, note: numeric_only=True
cols = ['MSRP', 'Engine HP', 'Engine Cylinders']
Q1 = df[cols].quantile(0.25, numeric_only=True)
Q3 = df[cols].quantile(0.75, numeric_only=True)
IQR = Q3 - Q1
print(IQR)
# Out:
# MSRP                21327.5
# Engine HP             130.0
# Engine Cylinders        2.0
# dtype: float64

# %% [markdown]
# Don't worry about the above values because it's not important to know each and every one of them because it's just important to know how to use this technique in order to remove the outliers.

# %%
# TODO: remove outliers using IQR,  note: numeric_only=True
cols = ['MSRP', 'Engine HP', 'Engine Cylinders']
Q1 = df[cols].quantile(0.25, numeric_only=True)
Q3 = df[cols].quantile(0.75, numeric_only=True)
IQR = Q3 - Q1
Lower = Q1 - 1.5 * IQR
Upper = Q3 + 1.5 * IQR
df_clean = df[cols].clip(lower=Lower, upper=Upper, axis=1)
df_clean
# Out:
#           MSRP  Engine HP  Engine Cylinders
# 0      46135.0      335.0               6.0
# 1      40650.0      300.0               6.0
# 2      36350.0      300.0               6.0
# 3      29450.0      230.0               6.0
# 4      34500.0      230.0               6.0
# ...        ...        ...               ...
# 11909  46120.0      300.0               6.0
# 11910  56670.0      300.0               6.0
# 11911  50620.0      300.0               6.0
# 11912  50920.0      300.0               6.0
# 11913  28995.0      221.0               6.0
#
# [10827 rows x 3 columns]

# %%
cols = ['MSRP', 'Engine HP', 'Engine Cylinders']
Q1 = df[cols].quantile(0.25, numeric_only=True)
Q3 = df[cols].quantile(0.75, numeric_only=True)
IQR = Q3 - Q1
Lower = Q1 - 1.5 * IQR
Upper = Q3 + 1.5 * IQR
df_clean = df[(df[cols] >= Lower) & (df[cols] <= Upper)]
df_clean
# Out:
#       Make Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0      NaN   NaN   NaN      335.0               6.0               NaN
# 1      NaN   NaN   NaN      300.0               6.0               NaN
# 2      NaN   NaN   NaN      300.0               6.0               NaN
# 3      NaN   NaN   NaN      230.0               6.0               NaN
# 4      NaN   NaN   NaN      230.0               6.0               NaN
# ...    ...   ...   ...        ...               ...               ...
# 11909  NaN   NaN   NaN      300.0               6.0               NaN
# 11910  NaN   NaN   NaN      300.0               6.0               NaN
# 11911  NaN   NaN   NaN      300.0               6.0               NaN
# 11912  NaN   NaN   NaN      300.0               6.0               NaN
# 11913  NaN   NaN   NaN      221.0               6.0               NaN
#
#       Driven_Wheels  highway MPG  city mpg     MSRP
# 0               NaN          NaN       NaN  46135.0
# 1               NaN          NaN       NaN  40650.0
# 2               NaN          NaN       NaN  36350.0
# 3               NaN          NaN       NaN  29450.0
# 4               NaN          NaN       NaN  34500.0
# ...             ...          ...       ...      ...
# 11909           NaN          NaN       NaN  46120.0
# 11910           NaN          NaN       NaN  56670.0
# 11911           NaN          NaN       NaN  50620.0
# 11912           NaN          NaN       NaN  50920.0
# 11913           NaN          NaN       NaN  28995.0
#
# [10827 rows x 10 columns]

# %% [markdown]
# As seen above there were around 1600 rows were outliers. But you cannot completely remove the outliers because even after you use the above technique there maybe 1–2 outlier unremoved but that ok because there were more than 100 outliers. Something is better than nothing.

# %% [markdown]
# 9.Plot different features against one another (scatter), against frequency (histogram)¶
#
#
# **Histogram**
#
# Histogram refers to the frequency of occurrence of variables in an interval. In this case, there are mainly 10 different types of car manufacturing companies, but it is often important to know who has the most number of cars. To do this histogram is one of the trivial solutions which lets us know the total number of car manufactured by a different company.

# %%
# TODO: plot a bar chart of the top 40 car makes by number of cars nlargest(40)
make_counts = df['Make'].value_counts().nlargest(40)
make_counts.plot(kind='bar', figsize=(15,6))
plt.title("Top 40 car makes by number of cars")
plt.xlabel("Car Make")
plt.ylabel("Number of cars")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Heat Maps**
#
# Heat Maps is a type of plot which is necessary when we need to find the dependent variables. One of the best way to find the relationship between the features can be done using heat maps. In the below heat map we know that the price feature depends mainly on the Engine Size, Horsepower, and Cylinders.

# %%
# TODO: compute correlation with df.corr(numeric_only=True), then plot a heatmap with sns.heatmap()
data = ['MSRP', 'Engine HP', 'Engine Cylinders']
corr_m = df[data].corr()
sns.heatmap(corr_m, cmap='coolwarm')
plt.show()

# %% [markdown]
# **Scatterplot**
#
# We generally use scatter plots to find the correlation between two variables. Here the scatter plots are plotted between Horsepower and Price and we can see the plot below. With the plot given below, we can easily draw a trend line. These features provide a good scattering of points.

# %%
# TODO: scatter plot HP vs Price
df.plot.scatter(x='Engine HP', y='MSRP')
plt.show()

# %%
# TODO: univariate — describe numeric columns
df.describe()
# Out:
#                Year     Engine HP  Engine Cylinders   highway MPG  \
# count  10827.000000  10827.000000      10827.000000  10827.000000
# mean    2010.896370    254.553062          5.691604     26.308119
# std        7.029534    109.841537          1.768551      7.504652
# min     1990.000000     55.000000          0.000000     12.000000
# 25%     2007.000000    173.000000          4.000000     22.000000
# 50%     2015.000000    240.000000          6.000000     25.000000
# 75%     2016.000000    303.000000          6.000000     30.000000
# max     2017.000000   1001.000000         16.000000    354.000000
#
#            city mpg          MSRP
# count  10827.000000  1.082700e+04
# mean      19.327607  4.249325e+04
# std        6.643567  6.229451e+04
# min        7.000000  2.000000e+03
# 25%       16.000000  2.197250e+04
# 50%       18.000000  3.084500e+04
# 75%       22.000000  4.330000e+04
# max      137.000000  2.065902e+06

# %%
# TODO: univariate — histogram of Price with kde
sns.histplot(data=df, x='MSRP', kde=True)
plt.ylim(0,3000)
plt.xlim(0, 10000)
plt.show()

# %%
# TODO: univariate — countplot of Transmission
sns.countplot(data=df, x='Transmission Type')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# 11. Multivariate analysis (relationships)
#
# Compare a numeric variable across groups (Price vs Transmission) and plot several numeric columns together (pairplot).

# %%
# TODO: bivariate — boxplot of Price by Transmission
sns.boxplot(data=df, x= 'Transmission Type', y='MSRP')
plt.xticks(rotation = 90)
plt.show()

# %%
df
# Out:
#           Make       Model  Year  Engine HP  Engine Cylinders  \
# 0          BMW  1 Series M  2011      335.0               6.0
# 1          BMW    1 Series  2011      300.0               6.0
# 2          BMW    1 Series  2011      300.0               6.0
# 3          BMW    1 Series  2011      230.0               6.0
# 4          BMW    1 Series  2011      230.0               6.0
# ...        ...         ...   ...        ...               ...
# 11909    Acura         ZDX  2012      300.0               6.0
# 11910    Acura         ZDX  2012      300.0               6.0
# 11911    Acura         ZDX  2012      300.0               6.0
# 11912    Acura         ZDX  2013      300.0               6.0
# 11913  Lincoln      Zephyr  2006      221.0               6.0
#
#       Transmission Type      Driven_Wheels  highway MPG  city mpg   MSRP
# 0                MANUAL   rear wheel drive           26        19  46135
# 1                MANUAL   rear wheel drive           28        19  40650
# 2                MANUAL   rear wheel drive           28        20  36350
# 3                MANUAL   rear wheel drive           28        18  29450
# 4                MANUAL   rear wheel drive           28        18  34500
# ...                 ...                ...          ...       ...    ...
# 11909         AUTOMATIC    all wheel drive           23        16  46120
# 11910         AUTOMATIC    all wheel drive           23        16  56670
# 11911         AUTOMATIC    all wheel drive           23        16  50620
# 11912         AUTOMATIC    all wheel drive           23        16  50920
# 11913         AUTOMATIC  front wheel drive           26        17  28995
#
# [10827 rows x 10 columns]

# %%
# TODO: multivariate — pairplot of HP, Cylinders, MPG-H, Price
cols = ['Engine HP', 'Engine Cylinders', 'highway MPG', 'MSRP']
sns.pairplot(df[cols])
plt.show()

# %% [markdown]
# 12. Feature engineering (dummy variables, scaling, binning)
#
# Create dummy variables for categorical columns with few levels. Scale numeric columns (keep the originals). Bin Price into Low / Medium / High.
#
# Do not one-hot encode `Make` (too many categories).

# %%
# TODO: use MinMaxScaler on Price and StandardScaler on HP (keep original columns)
# from sklearn.preprocessing import ?,?

# df['Price_minmax'] = ?
# df['HP_standard'] = ?
# df[['Price', 'Price_minmax', 'HP', 'HP_standard']].head()

# %%
cols = ['MSRP', 'Engine HP', 'Engine Cylinders']

Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)
IQR = Q3 - Q1

Lower = Q1 - 1.5 * IQR
Upper = Q3 + 1.5 * IQR

# Loại bỏ các dòng chứa outlier
df_clean = df[
    ((df[cols] >= Lower) & (df[cols] <= Upper)).all(axis=1)
]

print("Trước khi loại outlier:", len(df))
print("Sau khi loại outlier:", len(df_clean))
print("Số dòng bị loại:", len(df) - len(df_clean))
# Out:
# Trước khi loại outlier: 10827
# Sau khi loại outlier: 9836
# Số dòng bị loại: 991

# %%
# TODO: use pd.cut() to bin Price into Low / Medium / High
# df['Price_bin']

# %% [markdown]
# 13. Summary
#
# Write 4–5 insights from the plots and tables. These are associations, not causal claims.
#
# Examples to check:
# - Which Make has the most cars?
# - Does Price rise with HP?
# - Which numeric features are most correlated with Price?
# - How many rows were removed as outliers?

# %% [markdown]
# # TODO: write insights
# - Hãng xe có số lượng xe xuất hiện nhiều nhất trong tập dữ liệu là 'Chevrolet', điều này cho thấy hãng này có số lượng mẫu xe được ghi nhận cao nhất.
# - Giá xe (MSRP) có xu hướng tăng khi công suất động cơ (Engine HP) tăng, cho thấy hai biến này có mối tương quan thuận.
# - Công suất động cơ (Engine HP) và số xi-lanh (Engine Cylinders) có mối tương quan tương đối rõ với giá xe (MSRP).
# - Có 991 dòng dữ liệu bị loại bỏ do chứa giá trị ngoại lai trong các biến MSRP, Engine HP hoặc Engine Cylinders.
#
# Caveat: correlation is not causation.
